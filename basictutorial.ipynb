# %%
# using print function
print("hello world")
# Out:
# hello world

# %%
#using type function

x=10
print(type(x))

b="python"
print(type(b))

z=19.5
print(type(z))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>

# %%
# user input
x=input("enter a number ")
print("number is",x)
# Out:
# enter a number 2
# number is 2
